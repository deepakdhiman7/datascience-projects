# %% [markdown]
# In this project, we will use different txt and CSV files and clean them to ready for data analysis. **As part of this project, we will drop unnecessary columns, take care of null values, change the index of the dataframe, observe the data types of each column, prepare them to convert into relevant pandas data types to make it ready for further analysis.**
#
# **We will also use applymap() function with custom function to clean different coulumns in one go. We will also perform renaming of columns & lables and skipping rows.**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\DataScience\MyProjects\DataCleaning\BL-Flickr-Images-Book.csv')

# %%
df.head(2)
# Out:
#    Identifier Edition Statement      Place of Publication Date of Publication  \
# 0         206               NaN                    London         1879 [1878]
# 1         216               NaN  London; Virtue & Yorston                1868
#
#           Publisher                                              Title  \
# 0  S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1      Virtue & Co.  All for Greed. [A novel. The dedication signed...
#
#       Author                                  Contributors  Corporate Author  \
# 0      A. A.                               FORBES, Walter.               NaN
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
#
#    Corporate Contributors Former owner  Engraver Issuance type  \
# 0                     NaN          NaN       NaN   monographic
# 1                     NaN          NaN       NaN   monographic
#
#                                           Flickr URL  \
# ...

# %%
df.shape
# Out:
# (8287, 15)

# %%
# Dropping unnecessary coulumns.

df_drop = ['Edition Statement', 'Contributors', 'Corporate Author', 'Corporate Contributors', 'Former owner', 'Engraver', 'Issuance type', 'Shelfmarks']

df.drop(df_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                         Flickr URL
# 0      A. A.  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
# Reviewing null values.

df.isnull().sum()
# Out:
# Identifier                 0
# Place of Publication       0
# Date of Publication      181
# Publisher               4195
# Title                      0
# Author                  1778
# Flickr URL                 0
# dtype: int64

# %%
# Checking if identifier can be used as index

df['Identifier'].is_unique
# Out:
# True

# %%
#Changing the index of the dataframe

df.set_index('Identifier', inplace=True)

# %%
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
# Reviewing data-types of each column

print(df.dtypes)
# Out:
# Place of Publication    object
# Date of Publication     object
# Publisher               object
# Title                   object
# Author                  object
# Flickr URL              object
# dtype: object

# %%
# Cleaning the "Date of Publication" column 

extr = df['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object

# %%
df['Date of Publication'] = pd.to_numeric(extr)

# %%
df.dtypes
# Out:
# Place of Publication     object
# Date of Publication     float64
# Publisher                object
# Title                    object
# Author                   object
# Flickr URL               object
# dtype: object

# %%
df['Date of Publication'].isnull().sum()/len(df)
# Out:
# 0.11789549897429709

# %%
print(df.loc[4157862])
print(df.loc[4159587])
# Out:
# Place of Publication                                  Newcastle-upon-Tyne
# Date of Publication                                                  1867
# Publisher                                                      T. Fordyce
# Title                   Local Records; or, Historical Register of rema...
# Author                      FORDYCE, T. - Printer, of Newcastle-upon-Tyne
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4157862, dtype: object
# Place of Publication                                  Newcastle upon Tyne
# Date of Publication                                                  1834
# Publisher                                                Mackenzie & Dent
# Title                   An historical, topographical and descriptive v...
# Author                                              Mackenzie, E. (Eneas)
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4159587, dtype: object

# %%
df.head()
# Out:
#                 Place of Publication  Date of Publication  \
# Identifier
# 206                           London               1879.0
# 216         London; Virtue & Yorston               1868.0
# 218                           London               1869.0
# 472                           London               1851.0
# 480                           London               1857.0
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
# Cleaning the 'Place of Publication' coulumn

london = df['Place of Publication'].str.contains('London', case=False, regex=True)
oxford = df['Place of Publication'].str.contains('Oxford', case=False, regex=True)

# %%
df['Place of Publication'] = np.where(london, 'London', np.where(oxford, 'Oxford', df['Place of Publication'].str.replace('-',' ')))

# %%
df.head()
# Out:
#            Place of Publication  Date of Publication              Publisher  \
# Identifier
# 206                      London               1879.0       S. Tinsley & Co.
# 216                      London               1868.0           Virtue & Co.
# 218                      London               1869.0  Bradbury, Evans & Co.
# 472                      London               1851.0          James Darling
# 480                      London               1857.0   Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.
#
# ...

# %%
# Reviewing if hypens have been removed from the values.

print(df.loc[4157862])
print(df.loc[4159587])
# Out:
# Place of Publication                                  Newcastle upon Tyne
# Date of Publication                                                  1867
# Publisher                                                      T. Fordyce
# Title                   Local Records; or, Historical Register of rema...
# Author                      FORDYCE, T. - Printer, of Newcastle-upon-Tyne
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4157862, dtype: object
# Place of Publication                                  Newcastle upon Tyne
# Date of Publication                                                  1834
# Publisher                                                Mackenzie & Dent
# Title                   An historical, topographical and descriptive v...
# Author                                              Mackenzie, E. (Eneas)
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4159587, dtype: object

# %% [markdown]
# **Cleaning the Entire Dataset Using the applymap Function.**
#
# Below we will see that the “dirt” is not localized to one column but is more spread out and how to improve it. We will use applymap() function with a custom function to accomplish our goal.

# %%
#  We have a file 'unniversity_towns.txt', which has state names written followed by “[edit]” substring in them. We used this pattern by creating a list 
#  of (state, city) tuples and wrapping that list in a DataFrame.

university_towns = []

with open(r'C:\Users\user\Desktop\DataScience\MyProjects\DataCleaning\university_towns.txt') as file:
    for line in file:
        if '[edit]' in line:
            state = line
        else:
            university_towns.append((state, line))

# %%
university_towns[:5]
# Out:
# [('Alabama[edit]\n', 'Auburn (Auburn University)[1]\n'),
#  ('Alabama[edit]\n', 'Florence (University of North Alabama)\n'),
#  ('Alabama[edit]\n', 'Jacksonville (Jacksonville State University)[2]\n'),
#  ('Alabama[edit]\n', 'Livingston (University of West Alabama)[2]\n'),
#  ('Alabama[edit]\n', 'Montevallo (University of Montevallo)[2]\n')]

# %%
# Creating data-frame from 'university_town' list

town_df = pd.DataFrame(university_towns, columns = ['State', 'RegionName'])

# %%
town_df.head()
# Out:
#              State                                         RegionName
# 0  Alabama[edit]\n                    Auburn (Auburn University)[1]\n
# 1  Alabama[edit]\n           Florence (University of North Alabama)\n
# 2  Alabama[edit]\n  Jacksonville (Jacksonville State University)[2]\n
# 3  Alabama[edit]\n       Livingston (University of West Alabama)[2]\n
# 4  Alabama[edit]\n         Montevallo (University of Montevallo)[2]\n

# %%
# Define a custom function to get rid of '(' and '[' in values in data frame

def get_citystate(item):
    if ' (' in item:
        return item[:item.find(' (')]
    elif '[' in item:
        return item[:item.find('[')]
    else:
        return item

# %%
# Now usinf applymap() , we can apply custom function to each value(cell) of data frame

town_df = town_df.applymap(get_citystate)
town_df.head()
# Out:
#      State    RegionName
# 0  Alabama        Auburn
# 1  Alabama      Florence
# 2  Alabama  Jacksonville
# 3  Alabama    Livingston
# 4  Alabama    Montevallo

# %% [markdown]
# **Below, we will work with another txt file and will learn rename columns, skipping rows.**
#
# In “olympics.csv” file below, we have insensible column names that are not easy to understand, or unimportant information in the first few and/or last rows, such as definitions of the terms in the dataset, or footnotes.
#
# We will rename columns and skip certain rows so that we can drill down to necessary information with correct and sensible labels.

# %%
olympics_df = pd.read_csv(r'C:\Users\user\Desktop\DataScience\MyProjects\DataCleaning\olympics.csv')
olympics_df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  ? Summer  01 !  02 !  03 !  Total  ? Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  ? Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %% [markdown]
# If we look at source file of this dataset, we will see that NaN above should really be something like “Country”, ? Summer is supposed to represent “Summer Games”, 01 ! should be “Gold”, and so on.
#
# We can skip rows and set the header while reading the CSV file by passing some parameters to the read_csv() function.

# %%
olympics_df = pd.read_csv(r'C:\Users\user\Desktop\DataScience\MyProjects\DataCleaning\olympics.csv', header=1)
olympics_df.head()
# Out:
#                 Unnamed: 0  ? Summer  01 !  02 !  03 !  Total  ? Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %% [markdown]
# Now, we will rename the columns.

# %%
# I will create a dictionary that will map with current column names to the new names.

new_names = {'Unnamed: 0': 'Country',
             '? Summer': 'Summer Olympics',
             '01 !': 'Gold',
             '02 !': 'Silver',
             '03 !': 'Bronze',
             '? Winter': 'Winter Olympics',
             '01 !.1': 'Gold.1',
             '02 !.1': 'Silver.1',
             '03 !.1': 'Bronze.1',
             '? Games': '# Games',
             '01 !.2': 'Gold.2',
             '02 !.2': 'Silver.2',
             '03 !.2': 'Bronze.2'}

# %%
# Now, we rename columns using rename function.

olympics_df.rename(columns= new_names, inplace=True)

# %%
olympics_df.head()
# Out:
#                    Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0        Afghanistan (AFG)               13     0       0       2      2
# 1            Algeria (ALG)               12     5       2       8     15
# 2          Argentina (ARG)               23    18      24      28     70
# 3            Armenia (ARM)                5     1       2       9     12
# 4  Australasia (ANZ) [ANZ]                2     3       4       5     12
#
#    Winter Olympics  Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# 0                0       0         0         0        0       13       0
# 1                3       0         0         0        0       15       5
# 2               18       0         0         0        0       41      18
# 3                6       0         0         0        0       11       1
# 4                0       0         0         0        0        2       3
#
#    Silver.2  Bronze.2  Combined total
# 0         0         2               2
# ...
